# %% [markdown]
# # Course #6 The complete Data Visualization Course, Excel, Tableau, Python, R

# %% [markdown]
# ## 3.- Bar Chart Homework

# %% [markdown]
# ### Bar Chart Homework Assignment – Create a Horizontal Bar Chart
#
# Your homework task is to use the data set from the section and create a Horizontal Bar Chart. In essence, the information on the chart will remain the same. But you’ll have swapped the x- and y-axis of the chart.
#
# This is your chance to explore the software, so you try out different options. For instance, choosing another color for the chart or exploring alternative chart formatting options.

# %% [markdown]
# ##### 0. Importing libs and reading data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print(pd.__version__)
print(sns.__version__)
# Out:
# 2.1.3
# 0.13.1

# %%
# Read / import the data
df_used_cars = pd.read_csv('bar_chart_data.csv')
df_used_cars
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %% [markdown]
# ##### 1. Using Seaborne barplot

# %%
fig= plt.figure(figsize=(9, 4))
splot = sns.barplot(x=df_used_cars['Cars Listings'],
                    y=df_used_cars['Brand'],
                    color='grey',
                    orient='h')
plt.title('Cars Listings by Brand', fontsize=16, fontweight='bold', loc='left')
plt.bar_label(splot.containers[0], fontweight='bold')
plt.ylabel(None)
plt.xlabel('Number of Listings')
plt.yticks(rotation=45)
plt.show()
fig.savefig('sns_bar_chart_h', bbox_inches='tight')

# %% [markdown]
# ##### 2. Using matplotlib plt.barh()

# %%
# Simple matplotlib bar chart
xy_size = 13

plt.figure(figsize=(10, 5))
plt.barh(y=df_used_cars['Brand'], width=df_used_cars['Cars Listings'],
        color='mediumblue')           # color='rgbwymc'  doesn't work 
plt.title('Used Cars Listing by Brand', fontsize=16, fontweight='bold')
plt.xlabel('Listing Cars', fontsize=xy_size)
plt.yticks(rotation=45, fontsize=xy_size)
plt.xticks(fontsize=xy_size)
plt.savefig('used_cars_bar_graph_h')
plt.show()
