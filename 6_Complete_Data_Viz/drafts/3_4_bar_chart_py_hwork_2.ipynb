# %% [markdown]
# # Course #6 The complete Data Visualization Course, Excel, Tableau, Python, R

# %% [markdown]
# ## 3.- Bar Chart Homework

# %% [markdown]
# ### Bar Chart Homework Assignment II – Create a bar chart of an ice cream shop sales
#
# You have a frequency distribution table with all the sales of an ice cream shop chain across four cities. Your task is to create a bar chart of the data.
#
# Create the chart.
# Make sure your chart has sufficient labeling and is well styled.
# Interpret the chart.

# %% [markdown]
# ##### 0. Importing libs and reading data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print(pd.__version__)
print(sns.__version__)
# Out:
# 2.1.3
# 0.13.1

# %%
# Read / import the data
df_used_cars = pd.read_csv('bar_chart_homework_data.csv')
df_used_cars
# Out:
#           Cities  Frequency
# 0       New York      12327
# 1             LA      17129
# 2  San Francisco      19923

# %% [markdown]
# ##### 1. Using Seaborne barplot

# %%
fig= plt.figure(figsize=(9, 6))
splot = sns.barplot(x=df_used_cars['Cities'],
                    y=df_used_cars['Frequency'],
                    color='midnightblue')
plt.title('Ice cream sales by Citie', fontsize=16, fontweight='bold', loc='left')
plt.bar_label(splot.containers[0], fontweight='bold')
plt.xlabel(None)
plt.ylabel('Number of sales')
plt.show()
fig.savefig('sns_bar_chart_hwork_2', bbox_inches='tight')
