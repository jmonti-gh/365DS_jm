# %% [markdown]
# # Course #6 The complete Data Visualization Course, Excel, Tableau, Python, R

# %% [markdown]
# ## 3.- Bar chart

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#sns.set()          # set default plots theme, alias for .set_theme()
sns.set_theme()     # set aspects of the visual theme for all matplotlib and seaborn plots

# %% [markdown]
# ### Assignment I - Create a Horizontal Bart Chart
# Your homework task is to use the data set from the section and create a Horizontal Bar Chart. In essence, the information on the chart will remain the same. But you’ll have swapped the x- and y-axis of the chart.
#
# This is your chance to explore the software, so you try out different options. For instance, choosing another color for the chart or exploring alternative chart formatting options.
#
# Tips:
#
# - Excel – in Excel this is known as a Clustered Bar chart. You can find it in the All Charts menu under Bar
# - Tableau – You could swap Brand and Cars Listing in the ‘Rows, Columns’ panel. Alternatively, after you have a regular bar chart, you could change to horizontal bars from the ‘Show me’ menu.
# - Python - in Matplotlib the barh() function creates a horizontal bar chart.
# - R – In ggplot2 you could add a coord_flip() function to your regular bar chart. The coord_flip can be used to swap the x- and y-axis on any plot, not just a bar chart.

# %%
# Import/read the data
df_used_cars = pd.read_csv('3_bar_chart_data.csv')
df_used_cars
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
# Horizontal bar chart
xy_size = 13
plt.figure(figsize=(9, 6))

bplot = plt.barh(y=df_used_cars['Brand'],
         width=df_used_cars['Cars Listings'],
         color='midnightblue')

plt.title('Used Cars Advertisements by Brand',
          fontdict={'size': xy_size + 2,
                    'weight': 'bold'},
            loc='left')

plt.yticks(rotation=45, fontsize=xy_size)
plt.xlabel('Number of Advertisements', fontsize=xy_size)
plt.bar_label(bplot,
              fontweight='bold',
              color='midnightblue',
              padding=4)
plt.savefig('3_homework_I_barh', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Assignment II - Create a bar chart of an ice-cream shop sales
# You have a frequency distribution table with all the sales of an ice cream shop chain across four cities. Your task is to create a bar chart of the data.
# 1. Create the chart.
# 2. Make sure your chart has sufficient labeling and is well styled.
# 3. Interpret the chart.

# %%
# Import the data into a DF
df_icream_sales = pd.read_csv('3_bar_chart_homework_data.csv')
df_icream_sales
# Out:
#           Cities  Frequency
# 0       New York      12327
# 1             LA      17129
# 2  San Francisco      19923

# %%
# Bar chart
xy_size = 13
bars_color = 'midnightblue'
fig = plt.figure()

bar_icream = plt.bar(x=df_icream_sales['Cities'],
                     height=df_icream_sales['Frequency'],
                     color=bars_color)

plt.title('Ice cream Sales by Site',
          loc='left',
          fontdict={'size': xy_size + 2,
                    'weight': 'bold'})

plt.bar_label(bar_icream,
              color='white',
              padding=-18,
              fontweight='bold')

plt.ylabel('Number of Ice creams sold',
           fontsize=xy_size)


plt.show()
fig.savefig('3_homework_II', bbox_inches='tight')

# %% [markdown]
# ### Interpretation
# - We can see that more ice creams were sold in San Francisco (in absolute value)
# - We can see this values en relation w/total inhabitants of each city or number of places where you sell in each city.
